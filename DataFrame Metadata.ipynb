# %%
import warnings
warnings.filterwarnings("ignore")

import math
import numpy as np
import pandas as pd
import seaborn as sns
import Metadata as meta
import matplotlib.pyplot as plt
from IPython.display import display
sns.set_theme()
sns.set_context("paper")

# %%
# credit_data = pd.read_csv('german_credit_data.csv')
# credit_data.to_hdf('credit_data.h5', key='df', mode='w')
credit_data = pd.read_hdf('credit_data.h5', 'df')
credit_data['Target'] = credit_data['Risk'].apply(lambda x: 1 if x == 'Risk' else 0)
display(credit_data)
# Out:
#                                 CustomerID CheckingStatus  LoanDuration  \
# 0     713a336c-a255-4e2d-9d57-90b3e99e2f06       0_to_200            31
# 1     140b363f-a3fe-4828-a33f-7284dfdb3969         less_0            18
# 2     43b7b51d-5eda-4860-b461-ebef3d3436f4         less_0            15
# 3     f40eaf08-e6d1-4765-ab20-c5f7faca1635       0_to_200            28
# 4     1728910a-d3ff-4799-ac50-203a3a58a3fb    no_checking            28
# ...                                    ...            ...           ...
# 4995  e77fa77b-78da-4607-a2fa-ede36c1e968f    greater_200            27
# 4996  6e71db4b-375c-42e1-b4a8-3292c007967a       0_to_200            11
# 4997  db501d22-e0c9-4f38-bf05-7f2c1df35395    no_checking            32
# 4998  802055d6-6aa7-4532-bf1c-0b8b114b483d       0_to_200            38
# 4999  53094239-82f4-4b14-b2e9-7a0355a10839         less_0            12
#
#                CreditHistory LoanPurpose  LoanAmount ExistingSavings  \
# ...

# %%
data = credit_data.copy()

# data information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                5000 non-null   object
#  1   CheckingStatus            5000 non-null   object
#  2   LoanDuration              5000 non-null   int64
#  3   CreditHistory             5000 non-null   object
#  4   LoanPurpose               5000 non-null   object
#  5   LoanAmount                5000 non-null   int64
#  6   ExistingSavings           5000 non-null   object
#  7   EmploymentDuration        5000 non-null   object
#  8   InstallmentPercent        5000 non-null   int64
#  9   Sex                       5000 non-null   object
#  10  OthersOnLoan              5000 non-null   object
#  11  CurrentResidenceDuration  5000 non-null   int64
#  12  OwnsProperty              5000 non-null   object
# ...

# %%
master = meta.dataframe_metadata(data)
display(master)
# Out:
#                         name    type  total  non_null  null  proc_null  \
# 0                 CustomerID  object   5000      5000     0        0.0
# 1             CheckingStatus  object   5000      5000     0        0.0
# 2               LoanDuration   int64   5000      5000     0        0.0
# 3              CreditHistory  object   5000      5000     0        0.0
# 4                LoanPurpose  object   5000      5000     0        0.0
# 5                 LoanAmount   int64   5000      5000     0        0.0
# 6            ExistingSavings  object   5000      5000     0        0.0
# 7         EmploymentDuration  object   5000      5000     0        0.0
# 8         InstallmentPercent   int64   5000      5000     0        0.0
# 9                        Sex  object   5000      5000     0        0.0
# 10              OthersOnLoan  object   5000      5000     0        0.0
# 11  CurrentResidenceDuration   int64   5000      5000     0        0.0
# ...

# %%
woe_tablea, iv = meta.calculate_woe(data, 'CheckingStatus', 'Target')
display(woe_tablea)
print(iv)
# Out:
#   CheckingStatus  total_number  number_bad  number_good  percent_total  \
# 0       0_to_200          1304         284         1020          26.08
# 1    greater_200           305         127          178           6.10
# 2         less_0          1398         130         1268          27.96
# 3    no_checking          1993        1129          864          39.86
#
#    percent_bad  percent_good  distribution_bad  distribution_good       woe  \
# 0         5.68         20.40          0.170060           0.306306  0.588435
# 1         2.54          3.56          0.076048           0.053453 -0.352552
# 2         2.60         25.36          0.077844           0.380781  1.587513
# 3        22.58         17.28          0.676048           0.259459 -0.957663
#
#    good_minus_bad        iv
# 0        0.136246  0.080172
# 1       -0.022594  0.007966
# 2        0.302936  0.480916
# 3       -0.416588  0.398952
# 0.9680050102834581

# %%
woe_tablea, iv = meta.calculate_woe(data, 'LoanPurpose', 'Target')
display(woe_tablea)
print(iv)
# Out:
#    LoanPurpose  total_number  number_bad  number_good  percent_total  \
# 0   appliances           561         287          274          11.22
# 1     business           146          52           94           2.92
# 2      car_new           945         118          827          18.90
# 3     car_used           808         200          608          16.16
# 4    education           167          70           97           3.34
# 5    furniture           853         284          569          17.06
# 6        other           113          73           40           2.26
# 7     radio_tv           755         326          429          15.10
# 8      repairs           283         160          123           5.66
# 9   retraining           164          42          122           3.28
# 10    vacation           205          58          147           4.10
#
#     percent_bad  percent_good  distribution_bad  distribution_good       woe  \
# ...

# %%
woe_tablea, iv = meta.calculate_woe(data, 'Housing', 'Target')
display(woe_tablea)
print(iv)
# Out:
#   Housing  total_number  number_bad  number_good  percent_total  percent_bad  \
# 0    free           739         526          213          14.78        10.52
# 1     own          3195        1025         2170          63.90        20.50
# 2    rent          1066         119          947          21.32         2.38
#
#    percent_good  distribution_bad  distribution_good       woe  \
# 0          4.26          0.314970           0.063964 -1.594158
# 1         43.40          0.613772           0.651652  0.059886
# 2         18.94          0.071257           0.284384  1.384027
#
#    good_minus_bad        iv
# 0       -0.251006  0.400143
# 1        0.037879  0.002268
# 2        0.213127  0.294973
# 0.697385102263666

# %%
woe_tablea, iv = meta.calculate_woe(data, 'InstallmentPercent', 'Target')
display(woe_tablea)
print(iv)
# Out:
#    InstallmentPercent  total_number  number_bad  number_good  percent_total  \
# 0                   1           513          33          480          10.26
# 1                   2          1192         176         1016          23.84
# 2                   3          1636         508         1128          32.72
# 3                   4          1206         605          601          24.12
# 4                   5           435         331          104           8.70
# 5                   6            18          17            1           0.36
#
#    percent_bad  percent_good  distribution_bad  distribution_good       woe  \
# 0         0.66          9.60          0.019760           0.144144  1.987130
# 1         3.52         20.32          0.105389           0.305105  1.062996
# 2        10.16         22.56          0.304192           0.338739  0.107571
# 3        12.10         12.02          0.362275           0.180480 -0.696782
# ...
