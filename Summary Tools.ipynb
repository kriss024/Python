# %%
# !pip install jupyter-summarytools

# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from summarytools import dfSummary, tabset
from IPython.display import display
# Config the matlotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
iris = sns.load_dataset("iris")
display(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
dfSummary(iris)
# Out:
# <style type="text/css">
# #T_019a7 thead>tr>th {
#   text-align: left;
# }
# #T_019a7_row0_col0, #T_019a7_row1_col0, #T_019a7_row2_col0, #T_019a7_row3_col0, #T_019a7_row4_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_019a7_row0_col1, #T_019a7_row1_col1, #T_019a7_row2_col1, #T_019a7_row3_col1, #T_019a7_row4_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_019a7_row0_col2, #T_019a7_row1_col2, #T_019a7_row2_col2, #T_019a7_row3_col2, #T_019a7_row4_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_019a7_row0_col3, #T_019a7_row1_col3, #T_019a7_row2_col3, #T_019a7_row3_col3, #T_019a7_row4_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
# ...

# %%
healthexp = sns.load_dataset("healthexp")
penguins = sns.load_dataset("penguins")

# %%
dfSummary(healthexp, is_collapsible = True)
# Out:
# <button type="button" class = "st-collapsible",
#     id = "btn-570" onclick = "coll_toggle_570()">Show Summary - healthexp</button>
#     <div class="st-content" id="cont-570">
#       <style type="text/css">
# #T_0c3b0 thead>tr>th {
#   text-align: left;
# }
# #T_0c3b0_row0_col0, #T_0c3b0_row1_col0, #T_0c3b0_row2_col0, #T_0c3b0_row3_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_0c3b0_row0_col1, #T_0c3b0_row1_col1, #T_0c3b0_row2_col1, #T_0c3b0_row3_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_0c3b0_row0_col2, #T_0c3b0_row1_col2, #T_0c3b0_row2_col2, #T_0c3b0_row3_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# ...

# %%
dfSummary(penguins, is_collapsible = True)
# Out:
# <button type="button" class = "st-collapsible",
#     id = "btn-6322" onclick = "coll_toggle_6322()">Show Summary - penguins</button>
#     <div class="st-content" id="cont-6322">
#       <style type="text/css">
# #T_68430 thead>tr>th {
#   text-align: left;
# }
# #T_68430_row0_col0, #T_68430_row1_col0, #T_68430_row2_col0, #T_68430_row3_col0, #T_68430_row4_col0, #T_68430_row5_col0, #T_68430_row6_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_68430_row0_col1, #T_68430_row1_col1, #T_68430_row2_col1, #T_68430_row3_col1, #T_68430_row4_col1, #T_68430_row5_col1, #T_68430_row6_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_68430_row0_col2, #T_68430_row1_col2, #T_68430_row2_col2, #T_68430_row3_col2, #T_68430_row4_col2, #T_68430_row5_col2, #T_68430_row6_col2 {
# ...

# %%
taxis = sns.load_dataset("taxis")
diamonds = sns.load_dataset("diamonds")
car_crashes = sns.load_dataset("car_crashes")

# %%
tabset({
    'taxis': dfSummary(taxis).to_html(),
    'diamonds': dfSummary(diamonds).to_html(),
    'car_crashes': dfSummary(car_crashes).to_html()
})
# Out:
# <div class="tab">
# <button id = "defaultOpen-2181" onclick = "OpenTab_2181(event, 'taxis-2181')" class="tablinks-2181">taxis</button>
# <button onclick = "OpenTab_2181(event, 'diamonds-2181')" class="tablinks-2181">diamonds</button>
# <button onclick = "OpenTab_2181(event, 'car_crashes-2181')" class="tablinks-2181">car_crashes</button>
# </div><div id = "taxis-2181" class="tabcontent-2181">
# <style type="text/css">
# #T_e3113 thead>tr>th {
#   text-align: left;
# }
# #T_e3113_row0_col0, #T_e3113_row1_col0, #T_e3113_row2_col0, #T_e3113_row3_col0, #T_e3113_row4_col0, #T_e3113_row5_col0, #T_e3113_row6_col0, #T_e3113_row7_col0, #T_e3113_row8_col0, #T_e3113_row9_col0, #T_e3113_row10_col0, #T_e3113_row11_col0, #T_e3113_row12_col0, #T_e3113_row13_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# ...

# %%
#!pip install -U sidetable

# %%
import sidetable

# %%
display(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.stb.freq(['species'])
# Out:
#       species  count    percent  cumulative_count  cumulative_percent
# 0   virginica     50  33.333333                50           33.333333
# 1  versicolor     50  33.333333               100           66.666667
# 2      setosa     50  33.333333               150          100.000000

# %%
iris.stb.freq(['species'], style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9d52e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d52e_level0_col0" class="col_heading level0 col0" >species</th>
#       <th id="T_9d52e_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_9d52e_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_9d52e_level0_col3" class="col_heading level0 col3" >cumulative_count</th>
#       <th id="T_9d52e_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d52e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d52e_row0_col0" class="data row0 col0" >virginica</td>
#       <td id="T_9d52e_row0_col1" class="data row0 col1" >50</td>
#       <td id="T_9d52e_row0_col2" class="data row0 col2" >33.33%</td>
#       <td id="T_9d52e_row0_col3" class="data row0 col3" >50</td>
# ...

# %%
titanic = sns.load_dataset("titanic")
titanic['c'] = 1
display(titanic)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  c
# ...

# %%
titanic.stb.freq(['class'])
# Out:
#     class  count    percent  cumulative_count  cumulative_percent
# 0   Third    491  55.106622               491           55.106622
# 1   First    216  24.242424               707           79.349046
# 2  Second    184  20.650954               891          100.000000

# %%
titanic.stb.freq(['class', 'survived'])
# Out:
#     class  survived  count    percent  cumulative_count  cumulative_percent
# 0   Third         0    372  41.750842               372           41.750842
# 1   First         1    136  15.263749               508           57.014590
# 2   Third         1    119  13.355780               627           70.370370
# 3  Second         0     97  10.886644               724           81.257015
# 4  Second         1     87   9.764310               811           91.021324
# 5   First         0     80   8.978676               891          100.000000

# %%
titanic.stb.freq(['class'], value='c')
# Out:
#     class    c    percent  cumulative_c  cumulative_percent
# 0   Third  491  55.106622           491           55.106622
# 1   First  216  24.242424           707           79.349046
# 2  Second  184  20.650954           891          100.000000

# %%
titanic.stb.freq(['class'], value='survived')
# Out:
#     class  survived    percent  cumulative_survived  cumulative_percent
# 0   First       136  39.766082                  136           39.766082
# 1   Third       119  34.795322                  255           74.561404
# 2  Second        87  25.438596                  342          100.000000

# %%
titanic.stb.freq(['survived'])
# Out:
#    survived  count    percent  cumulative_count  cumulative_percent
# 0         0    549  61.616162               549           61.616162
# 1         1    342  38.383838               891          100.000000

# %%
titanic.stb.freq(['class', 'who'], value='survived', thresh=80, other_label='All others')
# Out:
#         class         who  survived    percent  cumulative_survived  \
# 0       First       woman        89  26.023392                   89
# 1      Second       woman        60  17.543860                  149
# 2       Third       woman        56  16.374269                  205
# 3       First         man        42  12.280702                  247
# 4  All others  All others        95  27.777778                  342
#
#    cumulative_percent
# 0           26.023392
# 1           43.567251
# 2           59.941520
# 3           72.222222
# 4          100.000000

# %%
titanic.stb.counts(exclude='number')
# Out:
#              count  unique    most_freq  most_freq_count  least_freq  \
# sex            891       2         male              577      female
# adult_male     891       2         True              537       False
# alive          891       2           no              549         yes
# alone          891       2         True              537       False
# embarked       889       3            S              644           Q
# class          891       3        Third              491      Second
# who            891       3          man              537       child
# embark_town    889       3  Southampton              644  Queenstown
# deck           203       7            C               59           G
#
#              least_freq_count
# sex                       314
# adult_male                354
# alive                     342
# alone                     354
# embarked                   77
# class                     184
# who                        83
# ...

# %%
titanic.stb.missing()
# Out:
#              missing  total    percent
# deck             688    891  77.216611
# age              177    891  19.865320
# embarked           2    891   0.224467
# embark_town        2    891   0.224467
# survived           0    891   0.000000
# pclass             0    891   0.000000
# sex                0    891   0.000000
# sibsp              0    891   0.000000
# parch              0    891   0.000000
# fare               0    891   0.000000
# class              0    891   0.000000
# who                0    891   0.000000
# adult_male         0    891   0.000000
# alive              0    891   0.000000
# alone              0    891   0.000000
# c                  0    891   0.000000

# %%
titanic.stb.missing(clip_0=True, style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_213c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_213c8_level0_col0" class="col_heading level0 col0" >missing</th>
#       <th id="T_213c8_level0_col1" class="col_heading level0 col1" >total</th>
#       <th id="T_213c8_level0_col2" class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_213c8_level0_row0" class="row_heading level0 row0" >deck</th>
#       <td id="T_213c8_row0_col0" class="data row0 col0" >688</td>
#       <td id="T_213c8_row0_col1" class="data row0 col1" >891</td>
#       <td id="T_213c8_row0_col2" class="data row0 col2" >77.22%</td>
#     </tr>
#     <tr>
#       <th id="T_213c8_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_213c8_row1_col0" class="data row1 col0" >177</td>
#       <td id="T_213c8_row1_col1" class="data row1 col1" >891</td>
# ...

# %%
#!pip install dexplot

# %%
import dexplot as dxp
